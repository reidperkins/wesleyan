# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

data = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/mar_2019_mean_min_max_group1.txt")
diam = data[:,0]
df = data[:,1]
min_er = data[:,2]
max_er = data[:,3]

data2 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/mar_2019_im_15kms.txt")
im_mean = data2[:,1]
im_max = data2[:,2]
im_min = data2[:,3]

#data2 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv1_measured.txt")
#diam2 = data2[:,0]
#imv1 = data2[:,1]

#data3 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv1_ub_measured.txt")
#diam = data[:,0]
#imv1_ub = data3[:,1]

#data4 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv1_lb_measured.txt")
#diam = data[:,0]
#imv1_lb = data4[:,1]

#data11 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/jan_2019_max_df.txt")
#diam2 = data11[:,0]
#df_max = data11[:,1]

#data12 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv1_max.txt")
#diam2 = data11[:,0]
#imv1_max = data12[:,1]

#data13 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv1_ub_max.txt")
#diam2 = data11[:,0]
#imv1_ub_max = data13[:,1]

#data14 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv1_lb_max.txt")
#diam2 = data11[:,0]
#imv1_lb_max = data14[:,1]

#data15 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/mar_2019_mean_min_max_group1.txt")
#diam2 = data15[:,0]
#df_min = data15[:,1]

yup = max_er-df
ylo = df-min_er

plt.plot(diam, df, 'o', markerfacecolor='none', markeredgecolor='blue', label='Dark floor volume')
plt.errorbar(diam, df, yerr=(ylo, yup), capsize=3, color='blue', ls='None')
#plt.scatter(diam2, df_max, 'o', markerfacecolor='none', markeredgecolor='green', label='Dark floor volume (max)')
#plt.scatter(diam2, df_min, 'o', markerfacecolor='none', markeredgecolor='red', label='Dark floor volume (min)')
plt.plot(diam, im_max, color='orange')
plt.plot(diam, im_min, color='orange')
#plt.plot(diam2, df_max, 'o', markerfacecolor='none', markeredgecolor='green', label='Dark floor volume (max)')
#plt.plot(diam, imv1_ub_max, color='yellow')
#plt.plot(diam, imv1_lb_max, color='yellow')
plt.plot(diam, im_mean, color='orange', label='Impact melt volume (15 km/s chondrite)')
plt.yscale('log')
plt.xscale('log')
plt.legend(loc='upper left')
#plt.title('Dark floor and impact melt volumes', weight = 'bold')
plt.xlabel('Diameter (km)')
plt.ylabel('Volume ($km^3$)')
#plt.axis([-1, max(diam), -10, 1000])
plt.show()
#plt.savefig("mar_2019_df_group1.pdf", bbox_inches='tight')

# %%
data = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/df1_measured.txt")
diam = data[:,0]
df = data[:,1]

data5 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv2_measured.txt")
diam = data[:,0]
imv2 = data5[:,1]

data6 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv2_ub_measured.txt")
diam = data[:,0]
imv2_ub = data6[:,1]

data7 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv2_lb_measured.txt")
diam = data[:,0]
imv2_lb = data7[:,1]

plt.plot(diam, df, 'o', markerfacecolor='none', markeredgecolor='blue', label='Dark floor volume')
plt.plot(diam, imv2_ub, color='orange')
plt.plot(diam, imv2_lb, color='orange')
plt.plot(diam, imv2, label='Impact melt volume (25 km/s chondrite)')
plt.yscale('log')
plt.xscale('log')
plt.legend(loc='upper left')
plt.title('Dark floor and impact melt volumes', weight = 'bold')
plt.xlabel('Diameter (km)')
plt.ylabel('Volume ($km^3$)')
#plt.show()
plt.savefig("imv2.pdf", bbox_inches='tight')

# %%
data = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/df1_measured.txt")
diam = data[:,0]
df = data[:,1]

data8 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv3_measured.txt")
diam = data[:,0]
imv3 = data8[:,1]

data9 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv3_ub_measured.txt")
diam = data[:,0]
imv3_ub = data9[:,1]

data10 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv3_lb_measured.txt")
diam = data[:,0]
imv3_lb = data10[:,1]

plt.plot(diam, df, 'o', markerfacecolor='none', markeredgecolor='blue', label='Dark floor volume')
plt.plot(diam, imv2_ub, color='white')
plt.plot(diam, imv2_lb, color='white')
plt.plot(diam, imv2, label='Impact melt volume (50 km/s comet)')
plt.yscale('log')
plt.xscale('log')
plt.legend(loc='upper left')
plt.title('Dark floor and impact melt volumes', weight = 'bold')
plt.xlabel('Diameter (km)')
plt.ylabel('Volume ($km^3$)')
#plt.show()
plt.savefig("imv3_noerr.pdf", bbox_inches='tight')

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

#data = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/mar_2019_df_no_cp.txt")
#diam = data[:,0]
#df_max = data[:,1]
#df_min = data[:,2]
#im_mean = data[:,3]
#im_max = data[:,4]
#im_min = data[:,5]

data11 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/jan_2019_max_df.txt")
diam2 = data11[:,0]
df_max = data11[:,1]

data12 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv1_max.txt")
diam2 = data11[:,0]
imv1_max = data12[:,1]

data13 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv1_ub_max.txt")
diam2 = data11[:,0]
imv1_ub_max = data13[:,1]

data14 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv1_lb_max.txt")
diam2 = data11[:,0]
imv1_lb_max = data14[:,1]

data15 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/jan_2019_min_df.txt")
diam2 = data11[:,0]
df_min = data15[:,1]

plt.plot(diam2, df_max, 'o', markerfacecolor='none', markeredgecolor='blue', label='Dark floor volume (max)')
plt.plot(diam2, df_min, '^', markerfacecolor='none', markeredgecolor='green', label='Dark floor volume (min)')
plt.plot(diam2, imv1_ub_max, color='orange')
plt.plot(diam2, imv1_lb_max, color='orange')
plt.plot(diam2, imv1_max, color='orange', label='Impact melt volume (15 km/s chondrite)')
plt.yscale('log')
plt.xscale('log')
plt.legend(loc='upper left')
#plt.title('Dark floor and impact melt volumes', weight = 'bold')
plt.xlabel('Diameter (km)')
plt.ylabel('Volume ($km^3$)')
#plt.show()
plt.savefig("mar_2019_min_max_df.pdf", bbox_inches='tight')

# %%
data11 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/df_max.txt")
diam2 = data11[:,0]
df_max = data11[:,1]

data15 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv2_max.txt")
diam2 = data11[:,0]
imv2_max = data15[:,1]

data16 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv2_ub_max.txt")
diam2 = data11[:,0]
imv2_ub_max = data16[:,1]

data17 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv2_lb_max.txt")
diam2 = data11[:,0]
imv2_lb_max = data17[:,1]

plt.plot(diam2, df_max, 'o', markerfacecolor='none', markeredgecolor='blue', label='Dark floor volume (max)')
plt.plot(diam2, imv2_ub_max, color='orange')
plt.plot(diam2, imv2_lb_max, color='orange')
plt.plot(diam2, imv2_max, label='Impact melt volume (25 km/s chondrite)')
plt.yscale('log')
plt.xscale('log')
plt.legend(loc='upper left')
plt.title('Dark floor and impact melt volumes', weight = 'bold')
plt.xlabel('Diameter (km)')
plt.ylabel('Volume ($km^3$)')
#plt.show()
plt.savefig("imv2_max.pdf", bbox_inches='tight')

# %%
data11 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/jan_2019_max_df.txt")
diam2 = data11[:,0]
df_max = data11[:,1]

data18 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv3_max.txt")
diam2 = data11[:,0]
imv3_max = data18[:,1]

data19 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv3_ub_max.txt")
diam2 = data11[:,0]
imv3_ub_max = data19[:,1]

data20 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv3_lb_max.txt")
diam2 = data11[:,0]
imv3_lb_max = data20[:,1]

plt.plot(diam2, df_max, 'o', markerfacecolor='none', markeredgecolor='blue', label='Dark floor volume (max)')
plt.plot(diam2, imv3_ub_max, color='orange')
plt.plot(diam2, imv3_lb_max, color='orange')
plt.plot(diam2, imv3_max, label='Impact melt volume (50 km/s comet)')
plt.yscale('log')
plt.xscale('log')
plt.legend(loc='upper left')
plt.title('Dark floor and impact melt volumes', weight = 'bold')
plt.xlabel('Diameter (km)')
plt.ylabel('Volume ($km^3$)')
#plt.show()
plt.savefig("imv3_max.pdf", bbox_inches='tight')

# %%
data21 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/df_min.txt")
diam3 = data21[:,0]
df_min = data21[:,1]

data22 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv1_min.txt")
diam3 = data21[:,0]
imv1_min = data22[:,1]

data23 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv1_ub_min.txt")
diam3 = data21[:,0]
imv1_ub_min = data23[:,1]

data24 = np.genfromtxt("/Users/reidperkins/Documents/Wesleyan Research/statistics/imv1_lb_min.txt")
diam3 = data21[:,0]
imv1_lb_min = data24[:,1]

plt.plot(diam3, df_min, 'o', markerfacecolor='none', markeredgecolor='blue', label='Dark floor volume (min)')
plt.plot(diam3, imv1_ub_min, color='white')
plt.plot(diam3, imv1_lb_min, color='white')
plt.plot(diam3, imv1_min, label='Impact melt volume (15 km/s chondrite)')
plt.yscale('log')
plt.xscale('log')
plt.legend(loc='upper left')
plt.title('Dark floor and impact melt volumes', weight = 'bold')
plt.xlabel('Diameter (km)')
plt.ylabel('Volume ($km^3$)')
#plt.show()
plt.savefig("imv1_min_noerr.pdf", bbox_inches='tight')
